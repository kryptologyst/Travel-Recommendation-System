# %% [markdown]
# # Travel Recommendation System - Analysis Notebook
#
# This notebook demonstrates the travel recommendation system with data analysis and model comparison.

# %%
import sys
import os
sys.path.append('..')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from src.data.loader import TravelDataLoader
from src.models.recommenders import HybridRecommender
from src.evaluation.metrics import RecommendationMetrics

# Set up plotting
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")
